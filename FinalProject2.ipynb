# %% [markdown]
# <a href="https://colab.research.google.com/github/kittikhun62/DWDM21/blob/main/FinalProject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # สมาชิก

# %% [markdown]
# อ้างอิงข้อมูลจากเว๊บไซร์ www.data.go.th
#
# 1.ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 56 อ้างอิง : https://data.go.th/dataset/poppulationbyage56
#
# 2.ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 57 อ้างอิง : https://data.go.th/dataset/poppulationbyage57
#
# 3.ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 59 อ้างอิง : https://data.go.th/dataset/poppulationbyage59

# %% [markdown]
# #Data_Preprecessing

# %% [markdown]
# ### data ข้อมูลจำนวนประชากรในกรุงเทพมหานคร จำแนกตามอายุและเขต ปี 59,57,56

# %%
#Import the pandas library for visualizing data | การ import ให้สามารถเรียกใช้ไลบรารี่ pandas ในการ visualizing ชุดข้อมูล
import pandas as pd

# %% [markdown]
# Import the drive library for integration Google Colab with Google Drive to access any files on Google Drive.
#
# *  google.colab.

# %%
#Import the drive library from Google Colab module | การ import ให้สามารถเรียกใช้ไลบรารี่ drive ในการเข้าถึงไฟล์บน Google Drive
from google.colab import drive 

#Mount the drive on Google Colab to access any files from Google Drive | การ mount ไดร์ฟบน Google Colab ในการเข้าถึงไฟล์บน Google Drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read .csv files on the path with pandas | การอ่านไฟล์นามสกุล .csv ตามตำแหน่งของ path ที่กำหนด ด้วยไลบรารี่ pandas 

import os
path = '/content/drive/My Drive/PROJECT'

# %%
# การเเสดง dataframe ผ่านตัวเเปร data ที่เราให้เเทนค่าเอาไว้ โดยให้ 
#data0 = ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 56 
#data1 = ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 57 
#data2 = ข้อมูลจำนวนประชากรในกรุ่งเทพมหานคร จำเเนกตามอายุเเละเขตปี 59
#data3 = ข้อมูลชุมชนเเออัด

data0 = pd.read_csv(os.path.join(path,'poppulationbyage56dcode.csv'))
data1 = pd.read_csv(os.path.join(path,'poppulationbyage57dcode.csv'))
data2 = pd.read_csv(os.path.join(path,'poppulationbyage59dcode.csv'))
data3 = pd.read_csv(os.path.join(path,'ชุมชนแออัด.csv'))

# %%
data0
# Out:
#      id  dcode  sex  ... othernationalities_56  move_56  over100_56
# 0     1   1033    1  ...                  1018      207         yes
# 1     2   1033    2  ...                   645      175         yes
# 2     3   1018    1  ...                   920      350         yes
# 3     4   1018    2  ...                   753      323         yes
# 4     5   1046    1  ...                   162      115         yes
# ..  ...    ...  ...  ...                   ...      ...         ...
# 95   96   1003    2  ...                    70       70         yes
# 96   97   1041    1  ...                   150      552         yes
# 97   98   1041    2  ...                   118      157         yes
# 98   99   1017    1  ...                   383      234         yes
# 99  100   1017    2  ...                   272      177         yes
#
# [100 rows x 111 columns]

# %%
data1
# Out:
#      id  dcode  sex  ... othernationalities_57  move_57  over100_57
# 0     1   1033    1  ...                  1026      200         yes
# 1     2   1033    2  ...                   633      188         yes
# 2     3   1018    1  ...                   917      321         yes
# 3     4   1018    2  ...                   716      310         yes
# 4     5   1046    1  ...                   184      124         yes
# ..  ...    ...  ...  ...                   ...      ...         ...
# 95   96   1003    2  ...                    78       73         yes
# 96   97   1041    1  ...                   158      569         yes
# 97   98   1041    2  ...                   124      160         yes
# 98   99   1017    1  ...                   402      218         yes
# 99  100   1017    2  ...                   275      175         yes
#
# [100 rows x 111 columns]

# %%
data2
# Out:
#      id  dcode  sex  ... othernationalities_59  move_59  over100_59
# 0     1   1033    1  ...                  1032      204         yes
# 1     2   1033    2  ...                   628      158         yes
# 2     3   1018    1  ...                   815      299         yes
# 3     4   1018    2  ...                   680      276         yes
# 4     5   1046    1  ...                   230      112          no
# ..  ...    ...  ...  ...                   ...      ...         ...
# 95   96   1003    2  ...                   106       95         yes
# 96   97   1041    1  ...                   166      456         yes
# 97   98   1041    2  ...                   147      106         yes
# 98   99   1017    1  ...                   474      248         yes
# 99  100   1017    2  ...                   311      180         yes
#
# [100 rows x 111 columns]

# %%
data3 #ค่า slum ถ้าหาก มีค่าที่มากกว่า 12 เเปลว่า ชุมชนเขตนั้น เเออัด จะให้ค่าเป็น more ถ้านอยกว่า 12 เเปลว่าชุมชนในเขตนั้นไม่เเออัด จะให้ค่าเป็น nomore
# Out:
#     dcode                เขต  slum morethan&nomorethan
# 0    1033            คลองเตย    23                more
# 1    1018            คลองสาน    35                more
# 2    1046          คลองสามวา     0              nomore
# 3    1043           คันนายาว    14                more
# 4    1030            จตุจักร    21                more
# 5    1035             จอมทอง     3              nomore
# 6    1036           ดอนเมือง    16                more
# 7    1026             ดินแดง     8              nomore
# 8    1002              ดุสิต     9              nomore
# 9    1019           ตลิ่งชัน     8              nomore
# 10   1048           ทวีวัฒนา     0              nomore
# 11   1049            ทุ่งครุ     1              nomore
# 12   1015             ธนบุรี    44                more
# 13   1020         บางกอกน้อย    33                more
# 14   1016         บางกอกใหญ่    30                more
# 15   1006            บางกะปิ     8              nomore
# ...

# %% [markdown]
# ##เลือกข้อมูลที่ต้องการใช้

# %%
data0_RE = data0[['id','dcode','dcode_sex','othernationalities_56','sex']]
data0_RE
# Out:
#      id  dcode dcode_sex  othernationalities_56  sex
# 0     1   1033    1033_1                   1018    1
# 1     2   1033    1033_2                    645    2
# 2     3   1018    1018_1                    920    1
# 3     4   1018    1018_2                    753    2
# 4     5   1046    1046_1                    162    1
# ..  ...    ...       ...                    ...  ...
# 95   96   1003    1003_2                     70    2
# 96   97   1041    1041_1                    150    1
# 97   98   1041    1041_2                    118    2
# 98   99   1017    1017_1                    383    1
# 99  100   1017    1017_2                    272    2
#
# [100 rows x 5 columns]

# %%
data1_RE = data1[['dcode_sex','othernationalities_57']]
data1_RE
# Out:
#    dcode_sex  othernationalities_57
# 0     1033_1                   1026
# 1     1033_2                    633
# 2     1018_1                    917
# 3     1018_2                    716
# 4     1046_1                    184
# ..       ...                    ...
# 95    1003_2                     78
# 96    1041_1                    158
# 97    1041_2                    124
# 98    1017_1                    402
# 99    1017_2                    275
#
# [100 rows x 2 columns]

# %%
data2_RE = data2[['dcode_sex','othernationalities_59']]
data2_RE
# Out:
#    dcode_sex  othernationalities_59
# 0     1033_1                   1032
# 1     1033_2                    628
# 2     1018_1                    815
# 3     1018_2                    680
# 4     1046_1                    230
# ..       ...                    ...
# 95    1003_2                    106
# 96    1041_1                    166
# 97    1041_2                    147
# 98    1017_1                    474
# 99    1017_2                    311
#
# [100 rows x 2 columns]

# %% [markdown]
# ###รวมตาราง

# %%
merged_table_dcode_sex = data0_RE.merge(data1_RE,how='left',left_on='dcode_sex',right_on='dcode_sex')
merged_table_dcode_sex  #ครั้งที่ 1
# Out:
#      id  dcode dcode_sex  othernationalities_56  sex  othernationalities_57
# 0     1   1033    1033_1                   1018    1                   1026
# 1     2   1033    1033_2                    645    2                    633
# 2     3   1018    1018_1                    920    1                    917
# 3     4   1018    1018_2                    753    2                    716
# 4     5   1046    1046_1                    162    1                    184
# ..  ...    ...       ...                    ...  ...                    ...
# 95   96   1003    1003_2                     70    2                     78
# 96   97   1041    1041_1                    150    1                    158
# 97   98   1041    1041_2                    118    2                    124
# 98   99   1017    1017_1                    383    1                    402
# 99  100   1017    1017_2                    272    2                    275
#
# [100 rows x 6 columns]

# %%
merged_table_dcode_sex2 = merged_table_dcode_sex.merge(data2_RE,how='left',left_on='dcode_sex',right_on='dcode_sex')
merged_table_dcode_sex2  #ครั้งที่ 2
# Out:
#      id  dcode dcode_sex  ...  sex  othernationalities_57  othernationalities_59
# 0     1   1033    1033_1  ...    1                   1026                   1032
# 1     2   1033    1033_2  ...    2                    633                    628
# 2     3   1018    1018_1  ...    1                    917                    815
# 3     4   1018    1018_2  ...    2                    716                    680
# 4     5   1046    1046_1  ...    1                    184                    230
# ..  ...    ...       ...  ...  ...                    ...                    ...
# 95   96   1003    1003_2  ...    2                     78                    106
# 96   97   1041    1041_1  ...    1                    158                    166
# 97   98   1041    1041_2  ...    2                    124                    147
# 98   99   1017    1017_1  ...    1                    402                    474
# 99  100   1017    1017_2  ...    2                    275                    311
#
# ...

# %% [markdown]
# รวมตารางครั้งที่ 3

# %%
merged_table_dcode_sex3 =merged_table_dcode_sex2.merge(data3,how='left',left_on='dcode',right_on='dcode')
merged_table_dcode_sex3 # ให้ค่าสลัมถ้ามากกว่า 12 เเปลว่า ชุมชุนนั้นเป็นชุมชนเเออัด(More) ถ้าน้อยกว่า 12 จะไม่เป็นชุมชนเเออัด(Nomore)
# Out:
#      id  dcode dcode_sex  ...        เขต  slum  morethan&nomorethan
# 0     1   1033    1033_1  ...    คลองเตย    23                 more
# 1     2   1033    1033_2  ...    คลองเตย    23                 more
# 2     3   1018    1018_1  ...    คลองสาน    35                 more
# 3     4   1018    1018_2  ...    คลองสาน    35                 more
# 4     5   1046    1046_1  ...  คลองสามวา     0               nomore
# ..  ...    ...       ...  ...        ...   ...                  ...
# 95   96   1003    1003_2  ...    หนองจอก     0               nomore
# 96   97   1041    1041_1  ...    หลักสี่    17                 more
# 97   98   1041    1041_2  ...    หลักสี่    17                 more
# 98   99   1017    1017_1  ...   ห้วยขวาง    18                 more
# 99  100   1017    1017_2  ...   ห้วยขวาง    18                 more
#
# [100 rows x 10 columns]

# %%
merged_table_dcode_sex3.shape
# Out:
# (100, 10)

# %%
merged_table_dcode_sex3.isnull().any()
# Out:
# id                       False
# dcode                    False
# dcode_sex                False
# othernationalities_56    False
# sex                      False
# othernationalities_57    False
# othernationalities_59    False
# เขต                      False
# slum                     False
# morethan&nomorethan      False
# dtype: bool

# %% [markdown]
# # data minning

# %% [markdown]
# ประชากรปี 56

# %%
merged_table_dcode_sex3
# Out:
#      id  dcode dcode_sex  ...        เขต  slum  morethan&nomorethan
# 0     1   1033    1033_1  ...    คลองเตย    23                 more
# 1     2   1033    1033_2  ...    คลองเตย    23                 more
# 2     3   1018    1018_1  ...    คลองสาน    35                 more
# 3     4   1018    1018_2  ...    คลองสาน    35                 more
# 4     5   1046    1046_1  ...  คลองสามวา     0               nomore
# ..  ...    ...       ...  ...        ...   ...                  ...
# 95   96   1003    1003_2  ...    หนองจอก     0               nomore
# 96   97   1041    1041_1  ...    หลักสี่    17                 more
# 97   98   1041    1041_2  ...    หลักสี่    17                 more
# 98   99   1017    1017_1  ...   ห้วยขวาง    18                 more
# 99  100   1017    1017_2  ...   ห้วยขวาง    18                 more
#
# [100 rows x 10 columns]

# %%
A0 = merged_table_dcode_sex3.drop(columns=['id','dcode','sex','othernationalities_57','othernationalities_59','เขต'])
A0 # นำเเค่ข้อมูล othernationalities_56 มาใช้ในการทำนายประชากรที่อยู่ในเขต ว่าถ้าหากเเออัดจะมีประชากรมาก ไม่เเอดอัดจะมีประชากรน้อย
# Out:
#    dcode_sex  othernationalities_56  slum morethan&nomorethan
# 0     1033_1                   1018    23                more
# 1     1033_2                    645    23                more
# 2     1018_1                    920    35                more
# 3     1018_2                    753    35                more
# 4     1046_1                    162     0              nomore
# ..       ...                    ...   ...                 ...
# 95    1003_2                     70     0              nomore
# 96    1041_1                    150    17                more
# 97    1041_2                    118    17                more
# 98    1017_1                    383    18                more
# 99    1017_2                    272    18                more
#
# [100 rows x 4 columns]

# %%
target = merged_table_dcode_sex3['sex']
target
# Out:
# 0     1
# 1     2
# 2     1
# 3     2
# 4     1
#      ..
# 95    2
# 96    1
# 97    2
# 98    1
# 99    2
# Name: sex, Length: 100, dtype: int64

# %%
A0['morethan&nomorethan'] = A0['morethan&nomorethan'].map({'more': 1 ,'nomore': 2 })
A0 #ใช้คำสั่ง map เพื่อเปลี่ยนข้อมูลในคอลัม  morethan&nomorethan ให้เป็นตัวเลข โดยให้ more = 1 เเละ nomore = 2
# Out:
#    dcode_sex  othernationalities_56  slum  morethan&nomorethan
# 0     1033_1                   1018    23                    1
# 1     1033_2                    645    23                    1
# 2     1018_1                    920    35                    1
# 3     1018_2                    753    35                    1
# 4     1046_1                    162     0                    2
# ..       ...                    ...   ...                  ...
# 95    1003_2                     70     0                    2
# 96    1041_1                    150    17                    1
# 97    1041_2                    118    17                    1
# 98    1017_1                    383    18                    1
# 99    1017_2                    272    18                    1
#
# [100 rows x 4 columns]

# %%
X = A0.values
X
# Out:
# array([['1033_1', 1018, 23, 1],
#        ['1033_2', 645, 23, 1],
#        ['1018_1', 920, 35, 1],
#        ['1018_2', 753, 35, 1],
#        ['1046_1', 162, 0, 2],
#        ['1046_2', 105, 0, 2],
#        ['1043_1', 157, 14, 1],
#        ['1043_2', 103, 14, 1],
#        ['1030_1', 457, 21, 1],
#        ['1030_2', 342, 21, 1],
#        ['1035_1', 735, 3, 2],
#        ['1035_2', 564, 3, 2],
#        ['1036_1', 222, 16, 1],
#        ['1036_2', 137, 16, 1],
#        ['1026_1', 459, 8, 2],
#        ['1026_2', 403, 8, 2],
#        ['1002_1', 707, 9, 2],
#        ['1002_2', 375, 9, 2],
#        ['1019_1', 232, 8, 2],
#        ['1019_2', 184, 8, 2],
#        ['1048_1', 180, 0, 2],
#        ['1048_2', 176, 0, 2],
#        ['1049_1', 310, 1, 2],
#        ['1049_2', 260, 1, 2],
#        ['1015_1', 808, 44, 1],
#        ['1015_2', 667, 44, 1],
#        ['1020_1', 349, 33, 1],
#        ['1020_2', 315, 33, 1],
#        ['1016_1', 344, 30, 1],
#        ['1016_2', 305, 30, 1],
# ...

# %%
A0['morethan&nomorethan'].value_counts()
# Out:
# 2    56
# 1    44
# Name: morethan&nomorethan, dtype: int64

# %%
y = target.values
y
# Out:
# array([1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2])

# %% [markdown]
# train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=6)

# %%
X_train.shape
# Out:
# (50, 4)

# %% [markdown]
# train - validation เเบ่งอีกรอบ

# %%
X_train2, X_val, y_train2, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=6)

# %%
X_train2.shape #เหลือเเค่ 35 เเถว 4 คอลัม ที่จะนำมาทำต้นไม้
# Out:
# (25, 4)

# %% [markdown]
# import

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Define

# %%
mytree56 =  DecisionTreeClassifier(max_leaf_nodes=5,criterion='entropy')  #กำหนดให้มีมากสุด 5 node

# %% [markdown]
# Train

# %%
mytree56.fit(X_train2,y_train2)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=5,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Evaluate วัดผล

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Test 56

# %%
tree56_result = mytree56.predict(X_val) # เอาข้อมูลเรามา Test

# %%
accuracy_score(y_val, tree56_result ) #ความเเม่นยำของต้นไม้ได้ 40 เปอร์เซ็น
# Out:
# 0.52

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mytree56)
# Out:
# [Text(167.4, 195.696, 'X[2] <= 24.0\nentropy = 0.999\nsamples = 25\nvalue = [12, 13]'),
#  Text(111.60000000000001, 152.208, 'X[0] <= 10121.5\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]'),
#  Text(55.800000000000004, 108.72, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(167.4, 108.72, 'X[0] <= 10216.5\nentropy = 0.934\nsamples = 20\nvalue = [7, 13]'),
#  Text(111.60000000000001, 65.232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(223.20000000000002, 65.232, 'X[0] <= 10451.5\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]'),
#  Text(167.4, 21.744, 'entropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(279.0, 21.744, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(223.20000000000002, 152.208, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# ประชากรปี57

# %%
A1 = merged_table_dcode_sex3.drop(columns=['id','dcode','sex','othernationalities_56','othernationalities_59','เขต'])
A1
# Out:
#    dcode_sex  othernationalities_57  slum morethan&nomorethan
# 0     1033_1                   1026    23                more
# 1     1033_2                    633    23                more
# 2     1018_1                    917    35                more
# 3     1018_2                    716    35                more
# 4     1046_1                    184     0              nomore
# ..       ...                    ...   ...                 ...
# 95    1003_2                     78     0              nomore
# 96    1041_1                    158    17                more
# 97    1041_2                    124    17                more
# 98    1017_1                    402    18                more
# 99    1017_2                    275    18                more
#
# [100 rows x 4 columns]

# %%
target = merged_table_dcode_sex3['sex']
target #ข้อมูลเหมือนกันอยู้เเล้ว
# Out:
# 0     1
# 1     2
# 2     1
# 3     2
# 4     1
#      ..
# 95    2
# 96    1
# 97    2
# 98    1
# 99    2
# Name: sex, Length: 100, dtype: int64

# %%
A1['morethan&nomorethan'] = A1['morethan&nomorethan'].map({'more': 1 ,'nomore': 2 })
A1
# Out:
#    dcode_sex  othernationalities_57  slum  morethan&nomorethan
# 0     1033_1                   1026    23                    1
# 1     1033_2                    633    23                    1
# 2     1018_1                    917    35                    1
# 3     1018_2                    716    35                    1
# 4     1046_1                    184     0                    2
# ..       ...                    ...   ...                  ...
# 95    1003_2                     78     0                    2
# 96    1041_1                    158    17                    1
# 97    1041_2                    124    17                    1
# 98    1017_1                    402    18                    1
# 99    1017_2                    275    18                    1
#
# [100 rows x 4 columns]

# %%
X2 = A1.values
X2
# Out:
# array([['1033_1', 1026, 23, 1],
#        ['1033_2', 633, 23, 1],
#        ['1018_1', 917, 35, 1],
#        ['1018_2', 716, 35, 1],
#        ['1046_1', 184, 0, 2],
#        ['1046_2', 127, 0, 2],
#        ['1043_1', 162, 14, 1],
#        ['1043_2', 109, 14, 1],
#        ['1030_1', 473, 21, 1],
#        ['1030_2', 343, 21, 1],
#        ['1035_1', 715, 3, 2],
#        ['1035_2', 551, 3, 2],
#        ['1036_1', 229, 16, 1],
#        ['1036_2', 137, 16, 1],
#        ['1026_1', 450, 8, 2],
#        ['1026_2', 395, 8, 2],
#        ['1002_1', 705, 9, 2],
#        ['1002_2', 362, 9, 2],
#        ['1019_1', 231, 8, 2],
#        ['1019_2', 187, 8, 2],
#        ['1048_1', 192, 0, 2],
#        ['1048_2', 170, 0, 2],
#        ['1049_1', 319, 1, 2],
#        ['1049_2', 259, 1, 2],
#        ['1015_1', 767, 44, 1],
#        ['1015_2', 637, 44, 1],
#        ['1020_1', 337, 33, 1],
#        ['1020_2', 307, 33, 1],
#        ['1016_1', 346, 30, 1],
#        ['1016_2', 290, 30, 1],
# ...

# %%
A1['morethan&nomorethan'].value_counts()
# Out:
# 2    56
# 1    44
# Name: morethan&nomorethan, dtype: int64

# %%
y = target.values
y #ข้อมูลเหมือนกันอยู้เเล้ว
# Out:
# array([1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2])

# %% [markdown]
# train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train3, X_test1, y_train3, y_test1 = train_test_split(X, y, test_size=0.5, random_state=6)

# %%
X_train3.shape
# Out:
# (50, 4)

# %% [markdown]
# train - validation เเบ่งอีกรอบ

# %%
X_train4, X_val1, y_train4, y_val1 = train_test_split(X_train3, y_train3, test_size=0.5, random_state=6)

# %%
X_train4.shape #เหลือเเค่ 35 เเถว 4 คอลัม ที่จะนำมาทำต้นไม้
# Out:
# (25, 4)

# %% [markdown]
# import

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Define

# %%
mytree57 =  DecisionTreeClassifier(max_leaf_nodes=5,criterion='entropy')  #กำหนดให้มีมากสุด 5 node

# %% [markdown]
# Train

# %%
mytree57.fit(X_train4,y_train4)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=5,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Evaluate วัดผล

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Test 57

# %%
tree57_result = mytree57.predict(X_val1) # เอาข้อมูลเรามา Test

# %%
accuracy_score(y_val1, tree57_result ) #ความเเม่นยำของต้นไม้ได้ 50 เปอร์เซ็น
# Out:
# 0.52

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mytree57)
# Out:
# [Text(167.4, 195.696, 'X[2] <= 24.0\nentropy = 0.999\nsamples = 25\nvalue = [12, 13]'),
#  Text(111.60000000000001, 152.208, 'X[0] <= 10121.5\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]'),
#  Text(55.800000000000004, 108.72, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(167.4, 108.72, 'X[0] <= 10216.5\nentropy = 0.934\nsamples = 20\nvalue = [7, 13]'),
#  Text(111.60000000000001, 65.232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(223.20000000000002, 65.232, 'X[0] <= 10451.5\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]'),
#  Text(167.4, 21.744, 'entropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(279.0, 21.744, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(223.20000000000002, 152.208, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# ปี59

# %%
A2 = merged_table_dcode_sex3.drop(columns=['id','dcode','sex','othernationalities_56','othernationalities_57','เขต'])
A2
# Out:
#    dcode_sex  othernationalities_59  slum morethan&nomorethan
# 0     1033_1                   1032    23                more
# 1     1033_2                    628    23                more
# 2     1018_1                    815    35                more
# 3     1018_2                    680    35                more
# 4     1046_1                    230     0              nomore
# ..       ...                    ...   ...                 ...
# 95    1003_2                    106     0              nomore
# 96    1041_1                    166    17                more
# 97    1041_2                    147    17                more
# 98    1017_1                    474    18                more
# 99    1017_2                    311    18                more
#
# [100 rows x 4 columns]

# %%
target = merged_table_dcode_sex3['sex']
target #ข้อมูลเหมือนกันอยู้เเล้ว
# Out:
# 0     1
# 1     2
# 2     1
# 3     2
# 4     1
#      ..
# 95    2
# 96    1
# 97    2
# 98    1
# 99    2
# Name: sex, Length: 100, dtype: int64

# %%
A2['morethan&nomorethan'] = A2['morethan&nomorethan'].map({'more': 1 ,'nomore': 2 })
A2
# Out:
#    dcode_sex  othernationalities_59  slum  morethan&nomorethan
# 0     1033_1                   1032    23                    1
# 1     1033_2                    628    23                    1
# 2     1018_1                    815    35                    1
# 3     1018_2                    680    35                    1
# 4     1046_1                    230     0                    2
# ..       ...                    ...   ...                  ...
# 95    1003_2                    106     0                    2
# 96    1041_1                    166    17                    1
# 97    1041_2                    147    17                    1
# 98    1017_1                    474    18                    1
# 99    1017_2                    311    18                    1
#
# [100 rows x 4 columns]

# %%
X3 = A2.values
X3
# Out:
# array([['1033_1', 1032, 23, 1],
#        ['1033_2', 628, 23, 1],
#        ['1018_1', 815, 35, 1],
#        ['1018_2', 680, 35, 1],
#        ['1046_1', 230, 0, 2],
#        ['1046_2', 170, 0, 2],
#        ['1043_1', 696, 14, 1],
#        ['1043_2', 630, 14, 1],
#        ['1030_1', 505, 21, 1],
#        ['1030_2', 361, 21, 1],
#        ['1035_1', 595, 3, 2],
#        ['1035_2', 483, 3, 2],
#        ['1036_1', 277, 16, 1],
#        ['1036_2', 146, 16, 1],
#        ['1026_1', 401, 8, 2],
#        ['1026_2', 355, 8, 2],
#        ['1002_1', 475, 9, 2],
#        ['1002_2', 276, 9, 2],
#        ['1019_1', 234, 8, 2],
#        ['1019_2', 205, 8, 2],
#        ['1048_1', 247, 0, 2],
#        ['1048_2', 209, 0, 2],
#        ['1049_1', 337, 1, 2],
#        ['1049_2', 271, 1, 2],
#        ['1015_1', 646, 44, 1],
#        ['1015_2', 550, 44, 1],
#        ['1020_1', 302, 33, 1],
#        ['1020_2', 283, 33, 1],
#        ['1016_1', 300, 30, 1],
#        ['1016_2', 281, 30, 1],
# ...

# %%
A2['morethan&nomorethan'].value_counts()
# Out:
# 2    56
# 1    44
# Name: morethan&nomorethan, dtype: int64

# %%
y = target.values
y #ข้อมูลเหมือนกันอยู้เเล้ว
# Out:
# array([1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2,
#        1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2])

# %% [markdown]
# train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train5, X_test2, y_train5, y_test2 = train_test_split(X, y, test_size=0.5, random_state=6)

# %%
X_train5.shape
# Out:
# (50, 4)

# %% [markdown]
# train - validation เเบ่งอีกรอบ

# %%
X_train6, X_val2, y_train6, y_val2 = train_test_split(X_train5, y_train5, test_size=0.5, random_state=6)

# %%
X_train6.shape #เหลือเเค่ 35 เเถว 4 คอลัม ที่จะนำมาทำต้นไม้
# Out:
# (25, 4)

# %% [markdown]
# import

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Define

# %%
mytree59 =  DecisionTreeClassifier(max_leaf_nodes=5,criterion='entropy')  #กำหนดให้มีมากสุด 5 node

# %% [markdown]
# Train

# %%
mytree59.fit(X_train6,y_train6)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=5,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Evaluate วัดผล

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Test 59

# %%
tree59_result = mytree59.predict(X_val2) # เอาข้อมูลเรามา Test

# %%
accuracy_score(y_val2, tree59_result ) #ความเเม่นยำของต้นไม้ได้ 50 เปอร์เซ็น
# Out:
# 0.52

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mytree59)
# Out:
# [Text(167.4, 195.696, 'X[2] <= 24.0\nentropy = 0.999\nsamples = 25\nvalue = [12, 13]'),
#  Text(111.60000000000001, 152.208, 'X[0] <= 10121.5\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]'),
#  Text(55.800000000000004, 108.72, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(167.4, 108.72, 'X[0] <= 10216.5\nentropy = 0.934\nsamples = 20\nvalue = [7, 13]'),
#  Text(111.60000000000001, 65.232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(223.20000000000002, 65.232, 'X[0] <= 10451.5\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]'),
#  Text(167.4, 21.744, 'entropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(279.0, 21.744, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(223.20000000000002, 152.208, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# # Visualization

# %%
from matplotlib import pyplot as plt

# %%
merged_table_dcode_sex3
# Out:
#      id  dcode dcode_sex  ...        เขต  slum  morethan&nomorethan
# 0     1   1033    1033_1  ...    คลองเตย    23                 more
# 1     2   1033    1033_2  ...    คลองเตย    23                 more
# 2     3   1018    1018_1  ...    คลองสาน    35                 more
# 3     4   1018    1018_2  ...    คลองสาน    35                 more
# 4     5   1046    1046_1  ...  คลองสามวา     0               nomore
# ..  ...    ...       ...  ...        ...   ...                  ...
# 95   96   1003    1003_2  ...    หนองจอก     0               nomore
# 96   97   1041    1041_1  ...    หลักสี่    17                 more
# 97   98   1041    1041_2  ...    หลักสี่    17                 more
# 98   99   1017    1017_1  ...   ห้วยขวาง    18                 more
# 99  100   1017    1017_2  ...   ห้วยขวาง    18                 more
#
# [100 rows x 10 columns]

# %%
Plt_0 = merged_table_dcode_sex3[['sex','othernationalities_56','othernationalities_57','othernationalities_59']]
Plt_0
# Out:
#     sex  othernationalities_56  othernationalities_57  othernationalities_59
# 0     1                   1018                   1026                   1032
# 1     2                    645                    633                    628
# 2     1                    920                    917                    815
# 3     2                    753                    716                    680
# 4     1                    162                    184                    230
# ..  ...                    ...                    ...                    ...
# 95    2                     70                     78                    106
# 96    1                    150                    158                    166
# 97    2                    118                    124                    147
# 98    1                    383                    402                    474
# 99    2                    272                    275                    311
#
# [100 rows x 4 columns]

# %%
Plt_0_sex1 = Plt_0[Plt_0['sex'] == 1]
Plt_0_sex1
# Out:
#     sex  othernationalities_56  othernationalities_57  othernationalities_59
# 0     1                   1018                   1026                   1032
# 2     1                    920                    917                    815
# 4     1                    162                    184                    230
# 6     1                    157                    162                    696
# 8     1                    457                    473                    505
# 10    1                    735                    715                    595
# 12    1                    222                    229                    277
# 14    1                    459                    450                    401
# 16    1                    707                    705                    475
# 18    1                    232                    231                    234
# 20    1                    180                    192                    247
# ...

# %% [markdown]
# กราฟเเสดงความเเตกต่างประชากรของชาวต่างชาติเพศชายเเละเพศหญิงที่เข้ามาอยู่อาศัยในเเต่ละปี

# %%
Plt_0_sex1.describe()
# Out:
#         sex  ...  othernationalities_59
# count  50.0  ...               50.00000
# mean    1.0  ...              505.36000
# std     0.0  ...              341.48958
# min     1.0  ...              148.00000
# 25%     1.0  ...              300.25000
# 50%     1.0  ...              408.50000
# 75%     1.0  ...              590.25000
# max     1.0  ...             2076.00000
#
# [8 rows x 4 columns]

# %%
Plt_0_sex2 = Plt_0[Plt_0['sex'] == 2]
Plt_0_sex2
# Out:
#     sex  othernationalities_56  othernationalities_57  othernationalities_59
# 1     2                    645                    633                    628
# 3     2                    753                    716                    680
# 5     2                    105                    127                    170
# 7     2                    103                    109                    630
# 9     2                    342                    343                    361
# 11    2                    564                    551                    483
# 13    2                    137                    137                    146
# 15    2                    403                    395                    355
# 17    2                    375                    362                    276
# 19    2                    184                    187                    205
# 21    2                    176                    170                    209
# ...

# %%
Plt_0_sex2.describe()
# Out:
#         sex  ...  othernationalities_59
# count  50.0  ...              50.000000
# mean    2.0  ...             384.900000
# std     0.0  ...             247.579734
# min     2.0  ...             106.000000
# 25%     2.0  ...             240.500000
# 50%     2.0  ...             305.500000
# 75%     2.0  ...             443.250000
# max     2.0  ...            1526.000000
#
# [8 rows x 4 columns]

# %% [markdown]
# สรุปข้อมูล
#
#
# เพศ 1
# 1.   ประชากรสัญชาติอื่น ปี 56 เฉลี่ยมีจำนวน 502.180000
# 2.   ประชากรสัญชาติอื่น ปี 57 เฉลี่ยมีจำนวน 505.240000
# 3.   ประชากรสัญชาติอื่น ปี 59 เฉลี่ยมีจำนวน 505.360000
#
#
# เพศ 2
#
# 1.   ประชากรสัญชาติอื่น ปี 56 เฉลี่ยมีจำนวน 384.500000
# 2.   ประชากรสัญชาติอื่น ปี 57 เฉลี่ยมีจำนวน 383.260000
# 3.   ประชากรสัญชาติอื่น ปี 59 เฉลี่ยมีจำนวน 384.900000

# %%
import numpy as np

labels = ['56','57','59']
men_means1 = [502.18, 505.24, 505.36]
women_means2 = [384.5, 383.26, 384.90]

# %%
plt.bar([56,57,59,],men_means1)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar([56,57,59,],women_means2)
# Out:
# <BarContainer object of 3 artists>

# %%
width =0.45



plt.bar(np.array([0,1,2]) - width/2, men_means1, width=width, label = 'men')
plt.bar(np.array([0,1,2]) + width/2, women_means2, width=width, label = 'women')

plt.legend()

# %% [markdown]
# ตอบ จากกราฟการเปรียบเทียบจำนวนประชากรชาวต่างชาติ ระหว่าง ของปี 56 57 59 ไม่เเตกต่างกันมาก เมื่อเทียบกับเพศ จำนวนประชากรเพศชาย มากกว่าเพศหญิง

# %%
Plt_0_slum = merged_table_dcode_sex3[['dcode','othernationalities_56','othernationalities_57','othernationalities_59','slum']]
Plt_0_slum
# Out:
#     dcode  othernationalities_56  ...  othernationalities_59  slum
# 0    1033                   1018  ...                   1032    23
# 1    1033                    645  ...                    628    23
# 2    1018                    920  ...                    815    35
# 3    1018                    753  ...                    680    35
# 4    1046                    162  ...                    230     0
# ..    ...                    ...  ...                    ...   ...
# 95   1003                     70  ...                    106     0
# 96   1041                    150  ...                    166    17
# 97   1041                    118  ...                    147    17
# 98   1017                    383  ...                    474    18
# 99   1017                    272  ...                    311    18
#
# [100 rows x 5 columns]

# %%
Plt_0_slum_1 = Plt_0_slum[Plt_0_slum['slum'] < 12 ] 
Plt_0_slum_1
# Out:
#     dcode  othernationalities_56  ...  othernationalities_59  slum
# 4    1046                    162  ...                    230     0
# 5    1046                    105  ...                    170     0
# 10   1035                    735  ...                    595     3
# 11   1035                    564  ...                    483     3
# 14   1026                    459  ...                    401     8
# 15   1026                    403  ...                    355     8
# 16   1002                    707  ...                    475     9
# 17   1002                    375  ...                    276     9
# 18   1019                    232  ...                    234     8
# 19   1019                    184  ...                    205     8
# 20   1048                    180  ...                    247     0
# 21   1048                    176  ...                    209     0
# 22   1049                    310  ...                    337     1
# ...

# %%
Plt_0_slum_1.plot.scatter('dcode','othernationalities_56')

# %%
Plt_0_slum_1.plot.scatter('dcode','othernationalities_57')

# %%
Plt_0_slum_1.plot.scatter('dcode','othernationalities_59')

# %%
Plt_0_slum_2 = Plt_0_slum[Plt_0_slum['slum'] > 12 ]
Plt_0_slum_2
# Out:
#     dcode  othernationalities_56  ...  othernationalities_59  slum
# 0    1033                   1018  ...                   1032    23
# 1    1033                    645  ...                    628    23
# 2    1018                    920  ...                    815    35
# 3    1018                    753  ...                    680    35
# 6    1043                    157  ...                    696    14
# 7    1043                    103  ...                    630    14
# 8    1030                    457  ...                    505    21
# 9    1030                    342  ...                    361    21
# 12   1036                    222  ...                    277    16
# 13   1036                    137  ...                    146    16
# 24   1015                    808  ...                    646    44
# 25   1015                    667  ...                    550    44
# 26   1020                    349  ...                    302    33
# ...

# %%
Plt_0_slum_2.plot.scatter('dcode','othernationalities_56')

# %%
Plt_0_slum_1.plot.scatter('dcode','othernationalities_57')

# %%
Plt_0_slum_1.plot.scatter('dcode','othernationalities_59')
