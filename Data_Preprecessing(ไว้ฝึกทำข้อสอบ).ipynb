# %% [markdown]
# <a href="https://colab.research.google.com/github/kittikhun62/DWDM21/blob/main/Data_Preprecessing(%E0%B9%84%E0%B8%A7%E0%B9%89%E0%B8%9D%E0%B8%B6%E0%B8%81%E0%B8%97%E0%B8%B3%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%AA%E0%B8%AD%E0%B8%9A).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/MID'

# %%
data = pd.read_csv(os.path.join(path,'mf_portfif_1_th_06.csv'))

# %%
data
# Out:
#                                      ภูมิภาคและประเทศ  ... มิถุนายน_ปี_2564
# 0                                             Africa   ...     1.350281e+01
# 1                                           mauritius  ...              NaN
# 2                                            morocco   ...              NaN
# 3                                       south africa   ...     1.350281e+01
# 4                                               togo   ...              NaN
# ..                                                ...  ...              ...
# 85                                     supranational   ...              NaN
# 86                                             TOTAL   ...     1.763376e+06
# 87                                                NaN  ...              NaN
# 88   *Europe Region หมายถึง มูลค่าการลงทุนผ่านหน่ว...  ...              NaN
# 89                      **ไม่รวมสัญญาซื้อขายล่วงหน้า   ...              NaN
#
# [90 rows x 56 columns]

# %%
data['กรกฎาคม_ปี_2562']
# Out:
# 0             86.1
# 1                0
# 2            14.19
# 3            65.42
# 4             6.49
#           ...
# 85          275.86
# 86    1,688,435.04
# 87             NaN
# 88             NaN
# 89             NaN
# Name: กรกฎาคม_ปี_2562, Length: 90, dtype: object

# %%
data.isnull()
# Out:
#     ภูมิภาคและประเทศ  ธันวาคม_ปี_2559  ...  พฤษภาคม_ปี_2564  มิถุนายน_ปี_2564
# 0              False            False  ...            False             False
# 1              False            False  ...             True              True
# 2              False            False  ...             True              True
# 3              False            False  ...            False             False
# 4              False            False  ...             True              True
# ..               ...              ...  ...              ...               ...
# 85             False            False  ...             True              True
# 86             False            False  ...            False             False
# 87              True             True  ...             True              True
# 88             False             True  ...             True              True
# 89             False             True  ...             True              True
#
# [90 rows x 56 columns]

# %%
data.isnull().any()
# Out:
# ภูมิภาคและประเทศ      True
# ธันวาคม_ปี_2559       True
# มกราคม_ปี_2560        True
# กุมภาพันธ์_ปี_2560    True
# มีนาคม_ปี_2560        True
# เมษายน_ปี_2560        True
# พฤษภาคม_ปี_2560       True
# มิถุนายน_ปี_2560      True
# กรกฎาคม_ปี_2560       True
# สิงหาคม_ปี_2560       True
# กันยายน_ปี_2560       True
# ตุลาคม_ปี_2560        True
# พฤศจิกายน_ปี_2560     True
# ธันวาคม_ปี_2560       True
# มกราคม_ปี_2561        True
# กุมภาพันธ์_ปี_2561    True
# มีนาคม_ปี_2561        True
# เมษายน_ปี_2561        True
# พฤษภาคม_ปี_2561       True
# มิถุนายน_ปี_2561      True
# กรกฎาคม_ปี_2561       True
# สิงหาคม_ปี_2561       True
# กันยายน_ปี_2561       True
# ตุลาคม_ปี_2561        True
# พฤศจิกายน_ปี_2561     True
# ธันวาคม_ปี_2561       True
# มกราคม_ปี_2562        True
# กุมภาพันธ์_ปี_2562    True
# มีนาคม_ปี_2562        True
# เมษายน_ปี_2562        True
# พฤษภาคม_ปี_2562       True
# มิถุนายน_ปี_2562      True
# กรกฎาคม_ปี_2562       True
# สิงหาคม_ปี_2562       True
# ...

# %%
data.head(50)
# Out:
#                         ภูมิภาคและประเทศ  ... มิถุนายน_ปี_2564
# 0                                Africa   ...        13.502806
# 1                              mauritius  ...              NaN
# 2                               morocco   ...              NaN
# 3                          south africa   ...        13.502806
# 4                                  togo   ...              NaN
# 5                          Asia Pacific   ...    103903.246300
# 6                             australia   ...      1988.800918
# 7                              cambodia   ...              NaN
# 8                             indonesia   ...      7266.207955
# 9      lao people’s democratic republic   ...       980.961121
# 10                             malaysia   ...      3815.351802
# 11                              myanmar   ...              NaN
# 12                          new zealand   ...         4.983263
# 13                          philippines   ...       589.789940
# ...

# %%
data.tail(50)
# Out:
#                                      ภูมิภาคและประเทศ  ... มิถุนายน_ปี_2564
# 40                                     liechtenstein   ...     1.148835e+03
# 41                                         lithuania   ...              NaN
# 42                                        luxembourg   ...     3.461453e+05
# 43                                             malta   ...     1.502909e+01
# 44                                       netherlands   ...     8.780265e+01
# 45                                            norway   ...     1.532469e+01
# 46                                            poland   ...     3.740196e+01
# 47                                          portugal   ...              NaN
# 48                                           romania   ...              NaN
# 49                                          slovakia   ...              NaN
# 50                                          slovenia   ...              NaN
# ...

# %% [markdown]
# ##ตัด colums สุดท้ายเพราะข้อมูลไม่ตรงกัน เเละมีช่องว่าง เเล้วค่อยทำ  missing
